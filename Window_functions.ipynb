# %% [markdown]
# <a href="https://colab.research.google.com/github/makikah/Time_Series_Python/blob/main/Window_functions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Window functions**

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from scipy.special import beta
import scipy as sp
from scipy import signal
from scipy.fftpack import fft, fftshift

# %% [markdown]
# ##Tipos de Janelas

# %%
rectang = signal.boxcar(41)
freqrect = np.linspace(0, 41, len(rectang))

triang = signal.triang(41)
freqtria = np.linspace(0, 41, len(triang))

hamming = signal.hamming(41)
freqham = np.linspace(0, 41, len(hamming))

hann = signal.hann(41)
freqhan = np.linspace(0, 41, len(hann))

blackman = signal.blackman(41)
freqblac = np.linspace(0, 41, len(blackman))

harrisnutt = signal.nuttall(41)
freqharris = np.linspace(0, 41, len(harrisnutt))

kaiser = signal.kaiser(41, beta=5)
freqkaiser = np.linspace(0, 41, len(kaiser))

dolphcheby = signal.chebwin(41, at=100)
freqdolphcheby = np.linspace(0, 41, len(dolphcheby))

plt.figure(figsize=(10,8))
plt.rcParams["font.size"] = "16"
plt.plot(freqrect, rectang, freqtria, triang, freqham, hamming, freqhan, hann,
         freqblac, blackman, freqharris, harrisnutt, freqkaiser, kaiser,
         freqdolphcheby, dolphcheby)
plt.title("Janelas")
plt.ylabel("Amplitude")
plt.xlabel("")
plt.grid()
plt.legend(("Retangular", "Triangular", "Hamming", "Hann", "Blackman", 
            "Harris-Nuttal", "Kaiser β=5", "Dolph-Chebyshev"))
plt.savefig("output.pdf") 
plt.savefig("output1.pdf", dpi=400, transparent=False)
plt.show()

# %% [markdown]
# ## EXERCISE 2.1 A) Janela retangular com L = 10, 20, 40, ..
#
# Aumenta tamanho da janela (L), diminui transição.

# %%
window = signal.boxcar(10)
A = fft(window, 2048) / (len(window))
freq = np.linspace(0, 800, len(A))
response = 20 * np.log10(np.abs(fftshift(A)))

window1 = signal.boxcar(20)
A1 = fft(window1, 2048) / (len(window1))
freq1 = np.linspace(0, 800, len(A1))
response1 = 20 * np.log10(np.abs(fftshift(A1)))

window2 = signal.boxcar(40)
A2 = fft(window2, 2048) / (len(window2))
freq2 = np.linspace(0, 800, len(A2))
response2 = 20 * np.log10(np.abs(fftshift(A2)))

window3 = signal.boxcar(80)
A3 = fft(window3, 2048) / (len(window3))
freq3 = np.linspace(0, 800, len(A3))
response3 = 20 * np.log10(np.abs(fftshift(A3)))

window4 = signal.boxcar(120)
A4 = fft(window4, 2048) / (len(window4))
freq4 = np.linspace(0, 800, len(A4))
response4 = 20 * np.log10(np.abs(fftshift(A4)))

window5 = signal.boxcar(160)
A5 = fft(window5, 2048) / (len(window5))
freq5 = np.linspace(0, 800, len(A5))
response5 = 20 * np.log10(np.abs(fftshift(A5)))

window6 = signal.boxcar(180)
A6 = fft(window6, 2048) / (len(window6))
freq6 = np.linspace(0, 800, len(A6))
response6 = 20 * np.log10(np.abs(fftshift(A6)))

window7 = signal.boxcar(250)
A7 = fft(window7, 2048) / (len(window7))
freq7 = np.linspace(0, 800, len(A7))
response7 = 20 * np.log10(np.abs(fftshift(A7)))

plt.figure(figsize=(10,8))
plt.rcParams["font.size"] = "15"
plt.title("Janela Retangular")
plt.ylabel("[dB]")
plt.plot(freq, response, freq1, response1, freq2, response2, freq3, response3,
         freq4, response4, freq5, response5, freq6, response6, freq7, response7)
plt.axhline(-3, -100, 2, color="r", **{"ls":"-."})
# plt.axvline(380, -100, 2, color="b", **{"ls":"-."})
plt.grid()
plt.legend(("L = 10", "L = 20", "L = 40", "L = 80", "L = 120", 
            "L = 160", "L = 180", "L = 250"))
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: RuntimeWarning: divide by zero encountered in log10
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: RuntimeWarning: divide by zero encountered in log10
#   if __name__ == '__main__':
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:14: RuntimeWarning: divide by zero encountered in log10
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:19: RuntimeWarning: divide by zero encountered in log10
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:24: RuntimeWarning: divide by zero encountered in log10
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:29: RuntimeWarning: divide by zero encountered in log10
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:34: RuntimeWarning: divide by zero encountered in log10
# ...

# %%
#Cálculo do valor do lóbulo principal para janelas retangular, Hamming e Hann. 
#Aqui, é mudar nome da janela e valor de L. A linha vertical ajuda a obter a largura do lóbulo principal. 
window = signal.hamming(10)
A = fft(window, 2048) / (len(window)/2.0)
freq = np.linspace(0, 800, len(A))
response = 20 * np.log10(np.abs(fftshift(A)))

plt.figure(figsize=(10,8))
plt.rcParams["font.size"] = "15"
plt.title("Janela Hamming")
plt.ylabel("[dB]")
plt.plot(freq, response, label="L = 40")
plt.axhline(-3, -100, 2, color="r", **{"ls":"-."})
plt.axvline(345, -100, 2, color="b", **{"ls":"-."})
plt.axvline(455, -100, 2, color="b", **{"ls":"-."})
plt.grid()
plt.legend() #"L = 20", "L = 40", "L = 80", "L = 120", 
            #"L = 160", "L = 180", "L = 250"))
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: RuntimeWarning: divide by zero encountered in log10

# %% [markdown]
# ## EXERCISE 2.1 B) Janelas de Hamming e Hann com L = 10, 20, 40, ...

# %%
window = signal.hamming(10)
A = fft(window, 2048) / (len(window)/2.0)
freq = np.linspace(0, 800, len(A))
response = 20 * np.log10(np.abs(fftshift(A)))

window1 = signal.hamming(20)
A1 = fft(window1, 2048) / (len(window1)/2.0)
freq1 = np.linspace(0, 800, len(A1))
response1 = 20 * np.log10(np.abs(fftshift(A1)))

window2 = signal.hamming(40)
A2 = fft(window2, 2048) / (len(window2)/2.0)
freq2 = np.linspace(0, 800, len(A2))
response2 = 20 * np.log10(np.abs(fftshift(A2)))

window3 = signal.hamming(80)
A3 = fft(window3, 2048) / (len(window3)/2.0)
freq3 = np.linspace(0, 800, len(A3))
response3 = 20 * np.log10(np.abs(fftshift(A3)))

window4 = signal.hamming(120)
A4 = fft(window4, 2048) / (len(window4)/2.0)
freq4 = np.linspace(0, 800, len(A4))
response4 = 20 * np.log10(np.abs(fftshift(A4)))

window5 = signal.hamming(160)
A5 = fft(window5, 2048) / (len(window5)/2.0)
freq5 = np.linspace(0, 800, len(A5))
response5 = 20 * np.log10(np.abs(fftshift(A5)))

window6 = signal.hamming(180)
A6 = fft(window6, 2048) / (len(window6)/2.0)
freq6 = np.linspace(0, 800, len(A6))
response6 = 20 * np.log10(np.abs(fftshift(A6)))

window7 = signal.hamming(250)
A7 = fft(window7, 2048) / (len(window7)/2.0)
freq7 = np.linspace(0, 800, len(A7))
response7 = 20 * np.log10(np.abs(fftshift(A7)))

plt.figure(figsize=(10,8))
plt.rcParams["font.size"] = "15"
plt.title("Janela de Hamming")
plt.ylabel("[dB]")
plt.plot(freq, response, freq1, response1, freq2, response2, freq3, response3,
         freq4, response4, freq5, response5, freq6, response6, freq7, response7)
plt.axhline(-3, -400, 2, color="r", **{"ls":"-."})
plt.grid()
plt.legend(("L = 10", "L = 20", "L = 40", "L = 80", "L = 120", 
            "L = 160", "L = 180", "L = 250"))
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: RuntimeWarning: divide by zero encountered in log10
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: RuntimeWarning: divide by zero encountered in log10
#   if __name__ == '__main__':
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:19: RuntimeWarning: divide by zero encountered in log10
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:24: RuntimeWarning: divide by zero encountered in log10
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:29: RuntimeWarning: divide by zero encountered in log10
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:39: RuntimeWarning: divide by zero encountered in log10

# %%
window = signal.hann(10)
A = fft(window, 2048) / (len(window)/2.0)
freq = np.linspace(0, 800, len(A))
response = 20 * np.log10(np.abs(fftshift(A)))

window1 = signal.hann(20)
A1 = fft(window1, 2048) / (len(window1)/2.0)
freq1 = np.linspace(0, 800, len(A1))
response1 = 20 * np.log10(np.abs(fftshift(A1)))

window2 = signal.hann(40)
A2 = fft(window2, 2048) / (len(window2)/2.0)
freq2 = np.linspace(0, 800, len(A2))
response2 = 20 * np.log10(np.abs(fftshift(A2)))

window3 = signal.hann(80)
A3 = fft(window3, 2048) / (len(window3)/2.0)
freq3 = np.linspace(0, 800, len(A3))
response3 = 20 * np.log10(np.abs(fftshift(A3)))

window4 = signal.hann(120)
A4 = fft(window4, 2048) / (len(window4)/2.0)
freq4 = np.linspace(0, 800, len(A4))
response4 = 20 * np.log10(np.abs(fftshift(A4)))

window5 = signal.hann(160)
A5 = fft(window5, 2048) / (len(window5)/2.0)
freq5 = np.linspace(0, 800, len(A5))
response5 = 20 * np.log10(np.abs(fftshift(A5)))

window6 = signal.hann(180)
A6 = fft(window6, 2048) / (len(window6)/2.0)
freq6 = np.linspace(0, 800, len(A6))
response6 = 20 * np.log10(np.abs(fftshift(A6)))

window7 = signal.hann(250)
A7 = fft(window7, 2048) / (len(window7)/2.0)
freq7 = np.linspace(0, 800, len(A7))
response7 = 20 * np.log10(np.abs(fftshift(A7)))

plt.figure(figsize=(10,8))
plt.rcParams["font.size"] = "15"
plt.title("Janela de Hann")
plt.ylabel("[dB]")
plt.plot(freq, response, freq1, response1, freq2, response2, freq3, response3,
         freq4, response4, freq5, response5, freq6, response6, freq7, response7)
plt.axhline(-3, -200, 2, color="r", **{"ls":"-."})
# plt.axhline(-31.5, -200, 2, color="r", **{"ls":"-."})
plt.grid()
plt.legend(("L = 10", "L = 20", "L = 40", "L = 80", "L = 120", 
            "L = 160", "L = 180", "L = 250"))
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: RuntimeWarning: divide by zero encountered in log10
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: RuntimeWarning: divide by zero encountered in log10
#   if __name__ == '__main__':
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:14: RuntimeWarning: divide by zero encountered in log10
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:19: RuntimeWarning: divide by zero encountered in log10
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:24: RuntimeWarning: divide by zero encountered in log10
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:29: RuntimeWarning: divide by zero encountered in log10
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:34: RuntimeWarning: divide by zero encountered in log10

# %% [markdown]
# ## EXERCISE 2.1 C) Janela retangular normalizada com L = 10, 20, 40, ...

# %%
window = signal.boxcar(10)
A = fft(window, 2048) / (len(window))
freq = np.linspace(-0.5, 0.5, len(A))
response = 20 * np.log10(np.abs(fftshift(A / abs(A).max())))

windowA = signal.boxcar(20)
AA = fft(windowA, 2048) / (len(windowA))
freqA = np.linspace(-0.5, 0.5, len(AA))
responseA = 20 * np.log10(np.abs(fftshift(AA / abs(AA).max())))

windowB = signal.boxcar(40)
AB = fft(windowB, 2048) / (len(windowB))
freqB = np.linspace(-0.5, 0.5, len(AB))
responseB = 20 * np.log10(np.abs(fftshift(AB / abs(AB).max())))

windowC = signal.boxcar(80)
AC = fft(windowC, 2048) / (len(windowC))
freqC = np.linspace(-0.5, 0.5, len(AC))
responseC = 20 * np.log10(np.abs(fftshift(AC / abs(AC).max())))

windowD = signal.boxcar(120)
AD = fft(windowD, 2048) / (len(windowD))
freqD = np.linspace(-0.5, 0.5, len(AD))
responseD = 20 * np.log10(np.abs(fftshift(AD / abs(AD).max())))

windowE = signal.boxcar(160)
AE = fft(windowE, 2048) / (len(windowE))
freqE = np.linspace(-0.5, 0.5, len(AE))
responseE = 20 * np.log10(np.abs(fftshift(AE / abs(AE).max())))

windowF = signal.boxcar(180)
AF = fft(windowF, 2048) / (len(windowF))
freqF = np.linspace(-0.5, 0.5, len(AF))
responseF = 20 * np.log10(np.abs(fftshift(AF / abs(AF).max())))

windowG = signal.boxcar(250)
AG = fft(windowG, 2048) / (len(windowG)/2.0)
freqG = np.linspace(-0.5, 0.5, len(AG))
responseG = 20 * np.log10(np.abs(fftshift(AG / abs(AG).max())))

plt.figure(figsize=(10,8))
plt.rcParams["font.size"] = "15"
plt.axis([-0.5, 0.5, -80, 0])
plt.title("Janela Retangular normalizada")
plt.ylabel("[dB]")
plt.plot(freq, response, freqA, responseA, freqB, responseB, freqC, responseC, 
         freqD, responseD, freqE, responseE, freqF, responseF, freqG, responseG)
plt.axhline(-3, -80, 2, color="r", **{"ls":"-."})
plt.grid()
plt.legend(("L = 10", "L = 20", "L = 40", "L = 80", "L = 120", 
            "L = 160", "L = 180", "L = 250"))
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: RuntimeWarning: divide by zero encountered in log10
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: RuntimeWarning: divide by zero encountered in log10
#   if __name__ == '__main__':
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:14: RuntimeWarning: divide by zero encountered in log10
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:19: RuntimeWarning: divide by zero encountered in log10
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:24: RuntimeWarning: divide by zero encountered in log10
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:29: RuntimeWarning: divide by zero encountered in log10
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:34: RuntimeWarning: divide by zero encountered in log10
# ...

# %% [markdown]
# ## EXERCISE 2.1 D) Janelas de Hamming e Hann de 3-dB para uma largura normalizada de 3-dB

# %%
window = signal.hamming(10)
A = fft(window, 2048) / (len(window)/2.0)
freq = np.linspace(-0.5, 0.5, len(A))
response = 20 * np.log10(np.abs(fftshift(A/abs(A).max())))

window1 = signal.hamming(20)
A1 = fft(window1, 2048) / (len(window1)/2.0)
freq1 = np.linspace(-0.5, 0.5, len(A1))
response1 = 20 * np.log10(np.abs(fftshift(A1/abs(A1).max())))

window2 = signal.hamming(40)
A2 = fft(window2, 2048) / (len(window2)/2.0)
freq2 = np.linspace(-0.5, 0.5, len(A2))
response2 = 20 * np.log10(np.abs(fftshift(A2/abs(A2).max())))

window3 = signal.hamming(80)
A3 = fft(window3, 2048) / (len(window3)/2.0)
freq3 = np.linspace(-0.5, 0.5, len(A3))
response3 = 20 * np.log10(np.abs(fftshift(A3/abs(A3).max())))

window5 = signal.hamming(160)
A5 = fft(window5, 2048) / (len(window5)/2.0)
freq5 = np.linspace(-0.5, 0.5, len(A5))
response5 = 20 * np.log10(np.abs(fftshift(A5/abs(A5).max())))

window6 = signal.hamming(180)
A6 = fft(window6, 2048) / (len(window6)/2.0)
freq6 = np.linspace(-0.5, 0.5, len(A6))
response6 = 20 * np.log10(np.abs(fftshift(A6/abs(A6).max())))

window7 = signal.hamming(250)
A7 = fft(window7, 2048) / (len(window7)/2.0)
freq7 = np.linspace(-0.5, 0.5, len(A7))
response7 = 20 * np.log10(np.abs(fftshift(A7/abs(A7).max())))

plt.figure(figsize=(10,8))
plt.rcParams["font.size"] = "15"
plt.title("Janela de Hamming normalizada")
plt.ylabel("[dB]")
plt.plot(freq, response, freq1, response1, freq2, response2, freq3, response3,
         freq5, response5, freq6, response6, freq7, response7)
plt.axhline(-3, -400, 2, color="r", **{"ls":"-."})
plt.axis([-0.5, 0.5, -120, 0])
plt.grid()
plt.legend(("L = 10", "L = 20", "L = 40", "L = 80", "L = 160", 
            "L = 180", "L = 250"))
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: RuntimeWarning: divide by zero encountered in log10
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: RuntimeWarning: divide by zero encountered in log10
#   if __name__ == '__main__':
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:19: RuntimeWarning: divide by zero encountered in log10
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:24: RuntimeWarning: divide by zero encountered in log10
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:34: RuntimeWarning: divide by zero encountered in log10

# %%
window = signal.hann(10)
A = fft(window, 2048) / (len(window)/2.0)
freq = np.linspace(-0.5, 0.5, len(A))
response = 20 * np.log10(np.abs(fftshift(A/abs(A).max())))

window1 = signal.hann(20)
A1 = fft(window1, 2048) / (len(window1)/2.0)
freq1 = np.linspace(-0.5, 0.5, len(A1))
response1 = 20 * np.log10(np.abs(fftshift(A1/abs(A1).max())))

window2 = signal.hann(40)
A2 = fft(window2, 2048) / (len(window2)/2.0)
freq2 = np.linspace(-0.5, 0.5, len(A2))
response2 = 20 * np.log10(np.abs(fftshift(A2/abs(A2).max())))

window3 = signal.hann(80)
A3 = fft(window3, 2048) / (len(window3)/2.0)
freq3 = np.linspace(-0.5, 0.5, len(A3))
response3 = 20 * np.log10(np.abs(fftshift(A3/abs(A3).max())))

window5 = signal.hann(160)
A5 = fft(window5, 2048) / (len(window5)/2.0)
freq5 = np.linspace(-0.5, 0.5, len(A5))
response5 = 20 * np.log10(np.abs(fftshift(A5/abs(A5).max())))

window6 = signal.hann(180)
A6 = fft(window6, 2048) / (len(window6)/2.0)
freq6 = np.linspace(-0.5, 0.5, len(A6))
response6 = 20 * np.log10(np.abs(fftshift(A6/abs(A6).max())))

window7 = signal.hann(250)
A7 = fft(window7, 2048) / (len(window7)/2.0)
freq7 = np.linspace(-0.5, 0.5, len(A7))
response7 = 20 * np.log10(np.abs(fftshift(A7/abs(A7).max())))

plt.figure(figsize=(10,8))
plt.rcParams["font.size"] = "15"
plt.title("Janela de Hann normalizada")
plt.ylabel("[dB]")
plt.plot(freq, response, freq1, response1, freq2, response2, freq3, response3,
         freq5, response5, freq6, response6, freq7, response7)
plt.axhline(-3, -400, 2, color="r", **{"ls":"-."})
# plt.axhline(-31.5, -400, 2, color="r", **{"ls":"-."})
plt.axis([-0.5, 0.5, -120, 0])
plt.grid()
plt.legend(("L = 10", "L = 20", "L = 40", "L = 80", "L = 160", 
            "L = 180", "L = 250"))
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: RuntimeWarning: divide by zero encountered in log10
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: RuntimeWarning: divide by zero encountered in log10
#   if __name__ == '__main__':
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:14: RuntimeWarning: divide by zero encountered in log10
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:19: RuntimeWarning: divide by zero encountered in log10
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:24: RuntimeWarning: divide by zero encountered in log10
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:29: RuntimeWarning: divide by zero encountered in log10

# %% [markdown]
# ## EXERCISE 2.1 E)

# %%
window = signal.boxcar(20)
A = fft(window, 2048) / (len(window))
freq = np.linspace(-0.5, 0.5, len(A))
response = 20 * np.log10(np.abs(fftshift(A / abs(A).max())))

window1 = signal.hann(20)
A1 = fft(window1, 2048) / (len(window1)/2.0)
freq1 = np.linspace(-0.5, 0.5, len(A1))
response1 = 20 * np.log10(np.abs(fftshift(A1/abs(A1).max())))

window11 = signal.hamming(20)
A11 = fft(window11, 2048) / (len(window11)/2.0)
freq11 = np.linspace(-0.5, 0.5, len(A11))
response11 = 20 * np.log10(np.abs(fftshift(A11/abs(A11).max())))

plt.figure(figsize=(10,8))
plt.rcParams["font.size"] = "15"
plt.axis([-0.5, 0.5, -80, 0])
plt.title("Janela Retangular normalizada")
plt.ylabel("[dB]")
plt.plot(freq, response, freq1, response1, freq11, response11)
# plt.axhline(-3, -80, 2, color="r", **{"ls":"-."})
plt.grid()
plt.legend(("Boxcar: L = 20", "Hanning: L = 20", "Hamming: L = 20"))
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: RuntimeWarning: divide by zero encountered in log10
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: RuntimeWarning: divide by zero encountered in log10
#   if __name__ == '__main__':
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:14: RuntimeWarning: divide by zero encountered in log10

# %% [markdown]
# ## EXERCISE 2.1 F)
#
# Para janela de Kaiser,  $\beta$ altera a forma da janela, podendo até aproximar outras janelas.
#
# À medida que $\beta$ aumenta, a atenuação relativa do lóbulo lateral diminui e a largura do lóbulo principal aumenta. A Figura abaixo mostra como a atenuação relativa do lóbulo lateral permanece aproximadamente a mesma para um parâmetro $\beta$ fixo conforme o comprimento é variado.

# %%
kaiserw = signal.kaiser(40, beta=3)
A = fft(kaiserw, 2048) / (len(kaiserw)/2.0)
freq = np.linspace(-0.5, 0.5, len(A))
response = 20 * np.log10(np.abs(fftshift(A / abs(A).max())))

kaiserw2 = signal.kaiser(40, beta=5)
A2 = fft(kaiserw2, 2048) / (len(kaiserw2)/2.0)
freq22 = np.linspace(-0.5, 0.5, len(A2))
response22 = 20 * np.log10(np.abs(fftshift(A2 / abs(A2).max())))

kaiserwN = signal.kaiser(40, beta=8)
AN = fft(kaiserwN, 2048) / (len(kaiserwN)/2.0)
freqN = np.linspace(-0.5, 0.5, len(AN))
responseN = 20 * np.log10(np.abs(fftshift(AN / abs(AN).max())))

plt.figure(figsize=(10,8))
plt.rcParams["font.size"] = "15"
plt.axis([-0.5, 0.5, -80, 0])
plt.title("Janela de Kaiser")
plt.ylabel("[dB]")
plt.plot(freq, response, freq22, response22, freqN, responseN)
# plt.axhline(-3, -80, 2, color="r", **{"ls":"-."})
plt.grid()
plt.legend(("Kaiser $β$=3, L=40", "Kaiser $β$=5, L=40", "Kaiser $β$=8, L=40"))
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: RuntimeWarning: divide by zero encountered in log10
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: RuntimeWarning: divide by zero encountered in log10
#   if __name__ == '__main__':
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:14: RuntimeWarning: divide by zero encountered in log10

# %%
kaiserw = signal.kaiser(20, beta=8)
A = fft(kaiserw, 2048) / (len(kaiserw)/2.0)
freq = np.linspace(-0.5, 0.5, len(A))
response = 20 * np.log10(np.abs(fftshift(A / abs(A).max())))

kaiserw2 = signal.kaiser(40, beta=8)
A2 = fft(kaiserw2, 2048) / (len(kaiserw2)/2.0)
freq22 = np.linspace(-0.5, 0.5, len(A2))
response22 = 20 * np.log10(np.abs(fftshift(A2 / abs(A2).max())))

kaiserwN = signal.kaiser(80, beta=8)
AN = fft(kaiserwN, 2048) / (len(kaiserwN)/2.0)
freqN = np.linspace(-0.5, 0.5, len(AN))
responseN = 20 * np.log10(np.abs(fftshift(AN / abs(AN).max())))

plt.figure(figsize=(10,8))
plt.rcParams["font.size"] = "15"
plt.axis([-0.5, 0.5, -80, 0])
plt.title("Janela de Kaiser")
plt.ylabel("[dB]")
plt.plot(freq, response, freq22, response22, freqN, responseN)
# plt.axhline(-3, -80, 2, color="r", **{"ls":"-."})
plt.grid()
plt.legend(("Kaiser $β$=8, L=20", "Kaiser $β$=8, L=40", "Kaiser $β$=8, L=80"))
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: RuntimeWarning: divide by zero encountered in log10
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: RuntimeWarning: divide by zero encountered in log10
#   if __name__ == '__main__':
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:14: RuntimeWarning: divide by zero encountered in log10

# %% [markdown]
# ##EXERCISE 2.2 A) *altura máxima do lóbulo lateral*, que geralmente ocorre no primeiro lóbulo lateral para Janelas:
#
# - retangular,
#
# - triangular,
#
# - Hamming,
#
# - Hann,
#
# - Blackman e
#
# - Harris-Nuttall

# %%
#Rectangular Window
rectang = signal.boxcar(21)
Ar = fft(rectang, 2048) / (len(rectang))
freqr = np.linspace(-0.5, 0.5, len(Ar))
responser = 20 * np.log10(np.abs(fftshift(Ar / abs(Ar).max())))
rectang21 = signal.boxcar(41)
Ar21 = fft(rectang21, 2048) / (len(rectang21))
freqr21 = np.linspace(-0.5, 0.5, len(Ar21))
responser21 = 20 * np.log10(np.abs(fftshift(Ar21 / abs(Ar21).max())))
rectang81 = signal.boxcar(81)
Ar81 = fft(rectang81, 2048) / (len(rectang81))
freqr81 = np.linspace(-0.5, 0.5, len(Ar81))
responser81 = 20 * np.log10(np.abs(fftshift(Ar81 / abs(Ar81).max())))
plt.figure(figsize=(8,6))
plt.rcParams["font.size"] = "18"
plt.axis([-0.5, 0.5, -120, 0])
plt.title("Janela Retangular")
plt.ylabel("[dB]")
plt.plot(freqr, responser, freqr21, responser21, freqr81, responser81)
plt.axhline(-12.9, -120, 2, color="r", **{"ls":"-."})
plt.grid()
plt.legend(("L = 21", "L = 41", "L = 81"))
plt.show()

#Triangular window
triang = signal.triang(21)
At = fft(triang, 2048) / (len(triang))
freqt = np.linspace(-0.5, 0.5, len(At))
responset = 20 * np.log10(np.abs(fftshift(At / abs(At).max())))
triang41 = signal.triang(41)
At41 = fft(triang41, 2048) / (len(triang41))
freqt41 = np.linspace(-0.5, 0.5, len(At41))
responset41 = 20 * np.log10(np.abs(fftshift(At41 / abs(At41).max())))
triang81 = signal.triang(81)
At81 = fft(triang81, 2048) / (len(triang81))
freqt81 = np.linspace(-0.5, 0.5, len(At81))
responset81 = 20 * np.log10(np.abs(fftshift(At81 / abs(At81).max())))
plt.figure(figsize=(8,6))
plt.rcParams["font.size"] = "18"
plt.axis([-0.5, 0.5, -120, 0])
plt.title("Janela Triangular")
plt.ylabel("[dB]")
plt.plot(freqt, responset, freqt41, responset41, freqt81, responset81)
plt.axhline(-26., -120, 2, color="r", **{"ls":"-."})
plt.grid()
plt.legend(("L = 21", "L = 41", "L = 81"))
plt.show()

#Hamming
windowhm = signal.hamming(21)
Ahm = fft(windowhm, 2048) / (len(windowhm))
freqhm = np.linspace(-0.5, 0.5, len(Ahm))
responsehm = 20 * np.log10(np.abs(fftshift(Ahm / abs(Ahm).max())))
windowhm41 = signal.hamming(41)
Ahm41 = fft(windowhm41, 2048) / (len(windowhm41))
freqhm41 = np.linspace(-0.5, 0.5, len(Ahm41))
responsehm41 = 20 * np.log10(np.abs(fftshift(Ahm41 / abs(Ahm41).max())))
windowhm81 = signal.hamming(81)
Ahm81 = fft(windowhm81, 2048) / (len(windowhm81))
freqhm81 = np.linspace(-0.5, 0.5, len(Ahm81))
responsehm81 = 20 * np.log10(np.abs(fftshift(Ahm81 / abs(Ahm81).max())))
plt.figure(figsize=(8,6))
plt.rcParams["font.size"] = "18"
plt.axis([-0.5, 0.5, -120, 0])
plt.title("Janela de Hamming")
plt.ylabel("[dB]")
plt.plot(freqhm, responsehm, freqhm41, responsehm41, freqhm81, responsehm81)
plt.axhline(-41.4, -120, 2, color="r", **{"ls":"-."})
plt.grid()
plt.legend(("L = 21", "L = 41", "L = 81"))
plt.show()

#Hann
windowhn = signal.hann(21)
Ahn = fft(windowhn, 2048) / (len(windowhn))
freqhn = np.linspace(-0.5, 0.5, len(Ahn))
responsehn = 20 * np.log10(np.abs(fftshift(Ahn / abs(Ahn).max())))
windowhn41 = signal.hann(41)
Ahn41 = fft(windowhn41, 2048) / (len(windowhn41))
freqhn41 = np.linspace(-0.5, 0.5, len(Ahn41))
responsehn41 = 20 * np.log10(np.abs(fftshift(Ahn41 / abs(Ahn41).max())))
windowhn81 = signal.hann(81)
Ahn81 = fft(windowhn81, 2048) / (len(windowhn81))
freqhn81 = np.linspace(-0.5, 0.5, len(Ahn81))
responsehn81 = 20 * np.log10(np.abs(fftshift(Ahn81 / abs(Ahn81).max())))
plt.figure(figsize=(8,6))
plt.rcParams["font.size"] = "18"
plt.axis([-0.5, 0.5, -120, 0])
plt.title("Janela de Hann")
plt.ylabel("[dB]")
plt.plot(freqhn, responsehn, freqhn41, responsehn41, freqhn81, responsehn81)
plt.axhline(-31.5, -120, 2, color="r", **{"ls":"-."})
plt.grid()
plt.legend(("L = 21", "L = 41", "L = 81"))
plt.show()

#Blackman
windowbl = signal.blackman(21)
Abl = fft(windowbl, 2048) / (len(windowbl))
freqbl = np.linspace(-0.5, 0.5, len(Abl))
responsebl = 20 * np.log10(np.abs(fftshift(Abl / abs(Abl).max())))
windowbl41 = signal.blackman(41)
Abl41 = fft(windowbl41, 2048) / (len(windowbl41))
freqbl41 = np.linspace(-0.5, 0.5, len(Abl41))
responsebl41 = 20 * np.log10(np.abs(fftshift(Abl41 / abs(Abl41).max())))
windowbl81 = signal.blackman(81)
Abl81 = fft(windowbl81, 2048) / (len(windowbl81))
freqbl81 = np.linspace(-0.5, 0.5, len(Abl81))
responsebl81 = 20 * np.log10(np.abs(fftshift(Abl81 / abs(Abl81).max())))
plt.figure(figsize=(8,6))
plt.rcParams["font.size"] = "18"
plt.axis([-0.5, 0.5, -120, 0])
plt.title("Janela de Blackman")
plt.ylabel("[dB]")
plt.plot(freqbl, responsebl, freqbl41, responsebl41, freqbl81, responsebl81)
plt.axhline(-57.5, -120, 2, color="r", **{"ls":"-."})
plt.grid()
plt.legend(("L = 21", "L = 41", "L = 81"))
plt.show()

#Harris-Nuttal
windownu = signal.nuttall(21)
Anu = fft(windownu, 2048) / (len(windownu))
freqnu = np.linspace(-0.5, 0.5, len(Anu))
responsenu = 20 * np.log10(np.abs(fftshift(Anu / abs(Anu).max())))
windownu41 = signal.nuttall(41)
Anu41 = fft(windownu41, 2048) / (len(windownu41))
freqnu41 = np.linspace(-0.5, 0.5, len(Anu41))
responsenu41 = 20 * np.log10(np.abs(fftshift(Anu41 / abs(Anu41).max())))
windownu81 = signal.nuttall(81)
Anu81 = fft(windownu81, 2048) / (len(windownu81))
freqnu81 = np.linspace(-0.5, 0.5, len(Anu81))
responsenu81 = 20 * np.log10(np.abs(fftshift(Anu81 / abs(Anu81).max())))
plt.figure(figsize=(8,6))
plt.rcParams["font.size"] = "18"
plt.axis([-0.5, 0.5, -120, 0])
plt.title("Janela de Harris-Nuttal")
plt.ylabel("[dB]")
plt.plot(freqnu, responsenu, freqnu41, responsenu41, freqnu81, responsenu81)
plt.axhline(-90.5, -120, 2, color="r", **{"ls":"-."})
plt.grid()
plt.legend(("L = 21", "L = 41", "L = 81"))
plt.show()
# Out:
# <ipython-input-11-3b3a62eccef0>:77: RuntimeWarning: divide by zero encountered in log10
#   responsehn = 20 * np.log10(np.abs(fftshift(Ahn / abs(Ahn).max())))
# <ipython-input-11-3b3a62eccef0>:81: RuntimeWarning: divide by zero encountered in log10
#   responsehn41 = 20 * np.log10(np.abs(fftshift(Ahn41 / abs(Ahn41).max())))
# <ipython-input-11-3b3a62eccef0>:85: RuntimeWarning: divide by zero encountered in log10
#   responsehn81 = 20 * np.log10(np.abs(fftshift(Ahn81 / abs(Ahn81).max())))
# <ipython-input-11-3b3a62eccef0>:101: RuntimeWarning: divide by zero encountered in log10
#   responsebl = 20 * np.log10(np.abs(fftshift(Abl / abs(Abl).max())))
# <ipython-input-11-3b3a62eccef0>:105: RuntimeWarning: divide by zero encountered in log10
#   responsebl41 = 20 * np.log10(np.abs(fftshift(Abl41 / abs(Abl41).max())))

# %%
#A partir dessa célula, varia para cada janela o valor de L (21, 41, 81) e observe resultado de cada janela.

rectang = signal.boxcar(21)
Ar = fft(rectang, 2048) / (len(rectang))
freqr = np.linspace(-0.5, 0.5, len(Ar))
responser = 20 * np.log10(np.abs(fftshift(Ar / abs(Ar).max())))

#Triangular window
triang = signal.triang(21)
At = fft(triang, 2048) / (len(triang))
freqt = np.linspace(-0.5, 0.5, len(At))
responset = 20 * np.log10(np.abs(fftshift(At / abs(At).max())))

windowhm = signal.hamming(21)
Ahm = fft(windowhm, 2048) / (len(windowhm))
freqhm = np.linspace(-0.5, 0.5, len(Ahm))
responsehm = 20 * np.log10(np.abs(fftshift(Ahm / abs(Ahm).max())))

windowhn = signal.hann(21)
Ahn = fft(windowhn, 2048) / (len(windowhn))
freqhn = np.linspace(-0.5, 0.5, len(Ahn))
responsehn = 20 * np.log10(np.abs(fftshift(Ahn / abs(Ahn).max())))

windowbl = signal.blackman(21)
Abl = fft(windowbl, 2048) / (len(windowbl))
freqbl = np.linspace(-0.5, 0.5, len(Abl))
responsebl = 20 * np.log10(np.abs(fftshift(Abl / abs(Abl).max())))

windownu = signal.nuttall(21)
Anu = fft(windownu, 2048) / (len(windownu))
freqnu = np.linspace(-0.5, 0.5, len(Anu))
responsenu = 20 * np.log10(np.abs(fftshift(Anu / abs(Anu).max())))

plt.figure(figsize=(15,12))
plt.rcParams["font.size"] = "15"
plt.axis([-0.5, 0.5, -120, 0])
plt.title("Resposta em frequência de diferentes janelas L=21")
plt.ylabel("[dB]")
plt.plot(freqr, responser, freqt, responset, freqhn, responsehn,
         freqhm, responsehm, freqbl, responsebl, freqnu, responsenu)
plt.axhline(-12.9, -120, 2, color="r", **{"ls":"-."})
plt.axhline(-26.0, -120, 2, color="r", **{"ls":"-."})
plt.axhline(-31.5, -120, 2, color="r", **{"ls":"-."})
plt.axhline(-41.4, -120, 2, color="r", **{"ls":"-."})
plt.axhline(-58.5, -120, 2, color="r", **{"ls":"-."})
plt.axhline(-85.5, -120, 2, color="b", **{"ls":"-."})
plt.grid()
plt.legend(("Rectangular", "Triangular", "Hann", 
            "Hamming", "Blackman", "Harris-Nuttal"))
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:22: RuntimeWarning: divide by zero encountered in log10
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:27: RuntimeWarning: divide by zero encountered in log10

# %% [markdown]
# ##EXERCISE 2.2 B)

# %%
kaiser0 = signal.kaiser(41, beta=0)
A0 = fft(kaiser0, 2048) / (len(kaiser0)/2.0)
freq0 = np.linspace(-0.5, 0.5, len(A0))
response0 = 20 * np.log10(np.abs(fftshift(A0 / abs(A0).max())))

kaiser1 = signal.kaiser(41, beta=1)
A1 = fft(kaiser1, 2048) / (len(kaiser1)/2.0)
freq1 = np.linspace(-0.5, 0.5, len(A1))
response1 = 20 * np.log10(np.abs(fftshift(A1 / abs(A1).max())))

kaiser2 = signal.kaiser(41, beta=2)
A2 = fft(kaiser2, 2048) / (len(kaiser2)/2.0)
freq2 = np.linspace(-0.5, 0.5, len(A2))
response2 = 20 * np.log10(np.abs(fftshift(A2 / abs(A2).max())))

kaiser3 = signal.kaiser(41, beta=3)
A3 = fft(kaiser3, 2048) / (len(kaiser3)/2.0)
freq3 = np.linspace(-0.5, 0.5, len(A3))
response3 = 20 * np.log10(np.abs(fftshift(A3 / abs(A3).max())))

kaiser4 = signal.kaiser(41, beta=4)
A4 = fft(kaiser4, 2048) / (len(kaiser4)/2.0)
freq4 = np.linspace(-0.5, 0.5, len(A4))
response4 = 20 * np.log10(np.abs(fftshift(A4 / abs(A4).max())))

kaiser5 = signal.kaiser(41, beta=5)
A5 = fft(kaiser5, 2048) / (len(kaiser5)/2.0)
freq5 = np.linspace(-0.5, 0.5, len(A5))
response5 = 20 * np.log10(np.abs(fftshift(A5 / abs(A5).max())))

kaiser8 = signal.kaiser(41, beta=8)
A8 = fft(kaiser8, 2048) / (len(kaiser8)/2.0)
freq8 = np.linspace(-0.5, 0.5, len(A8))
response8 = 20 * np.log10(np.abs(fftshift(A8 / abs(A8).max())))

kaiser14 = signal.kaiser(41, beta=14)
A14 = fft(kaiser14, 2048) / (len(kaiser14)/2.0)
freq14 = np.linspace(-0.5, 0.5, len(A14))
response14 = 20 * np.log10(np.abs(fftshift(A14 / abs(A14).max())))

# kaiser25 = signal.kaiser(41, beta=25)
# A25 = fft(kaiser25, 2048) / (len(kaiser25)/2.0)
# freq25 = np.linspace(-0.5, 0.5, len(A25))
# response25 = 20 * np.log10(np.abs(fftshift(A25 / abs(A25).max())))

plt.figure(figsize=(15,12))
plt.rcParams["font.size"] = "15"
plt.axis([-0.5, 0.5, -120, 0])
plt.title("Janela de Kaiser com L = 41")
plt.ylabel("[dB]")
plt.plot(freq0, response0, freq1, response1, freq2, response2, freq3, response3, 
         freq4, response4, freq5, response5, freq8, response8, freq14, response14)
# plt.axhline(-3, -120, 2, color="r", **{"ls":"-."})
plt.grid()
plt.legend(("$β$=0", "$β$=1", "$β$=2", "$β$=3", "$β$=4", "$β$=5",
            "$β$=8", "$β$=14"))
plt.show()

# %% [markdown]
# ##EXERCISE 2.2 C)
#
# Quando o valor de $\beta$ é igual 5, o desempenho da janela de Kaiser (-43.5 dB) quase iguala a da janela de Hamming.

# %%
kaiserCC = signal.kaiser(41, beta=5)
ACC = fft(kaiserCC, 2048) / (len(kaiserCC)/2.0)
freqCC = np.linspace(-0.5, 0.5, len(ACC))
responseCC = 20 * np.log10(np.abs(fftshift(ACC / abs(ACC).max())))

hamm = signal.hamming(41)
Aham = fft(hamm, 2048) / (len(hamm))
freqham = np.linspace(-0.5, 0.5, len(Aham))
responseham = 20 * np.log10(np.abs(fftshift(Aham / abs(Aham).max())))

plt.figure(figsize=(10,8))
plt.rcParams["font.size"] = "15"
plt.axis([-0.5, 0.5, -120, 0])
plt.title("Resposta em frequência")
plt.ylabel("[dB]")
plt.plot(freqCC, responseCC, freqham, responseham)
plt.axhline(-43.5, -120, 2, color="r", **{"ls":"-."})
plt.axhline(-43.5, -120, 2, color="r", **{"ls":"-."})
plt.grid()
plt.legend(("Kaiser $β$=5", "Hamming"))
plt.show()

# %% [markdown]
# ##EXERCISE 2.2 D) Janela Dolph-Chebyshev

# %%
dolphchev = signal.chebwin(11, at=100)
Adolph = fft(dolphchev, 2048) / (len(dolphchev)/2.0)
freqdolph = np.linspace(-0.5, 0.5, len(Adolph))
respdolph = 20 * np.log10(np.abs(fftshift(Adolph / abs(Adolph).max())))

dolphchev21 = signal.chebwin(21, at=100)
Adolph21 = fft(dolphchev21, 2048) / (len(dolphchev21)/2.0)
freqdolph21 = np.linspace(-0.5, 0.5, len(Adolph21))
respdolph21 = 20 * np.log10(np.abs(fftshift(Adolph21 / abs(Adolph21).max())))

dolphchev41 = signal.chebwin(41, at=100)
Adolph41 = fft(dolphchev41, 2048) / (len(dolphchev41)/2.0)
freqdolph41 = np.linspace(-0.5, 0.5, len(Adolph41))
respdolph41 = 20 * np.log10(np.abs(fftshift(Adolph41 / abs(Adolph41).max())))

dolphchev81 = signal.chebwin(81, at=100)
Adolph81 = fft(dolphchev81, 2048) / (len(dolphchev81)/2.0)
freqdolph81 = np.linspace(-0.5, 0.5, len(Adolph81))
respdolph81 = 20 * np.log10(np.abs(fftshift(Adolph81 / abs(Adolph81).max())))

plt.figure(figsize=(10,8))
plt.rcParams["font.size"] = "15"
plt.axis([-0.5, 0.5, -120, 0])
plt.title("Resposta em frequência da janela Dolph-Chebyshev")
plt.ylabel("[dB]")
plt.plot(freqdolph, respdolph, freqdolph21, respdolph21,
         freqdolph41, respdolph41, freqdolph81, respdolph81)
plt.axhline(-3, -120, 2, color="r", **{"ls":"-."})
# plt.axhline(-43.5, -120, 2, color="r", **{"ls":"-."})
plt.grid()
plt.legend(("L=11", "L=21", "L=41", "L=81"))
plt.show()

# %% [markdown]
# ##EXERCISE 2.3 A) Prove that ENBW is independent of L for the rectangular window. Demonstrate that for the Hamming window, it is nearly independent of L
#
# Para responder nesta pergunta, basta variando L e observar o desempenho das janelas retangular e Hamming.
#
# ##EXERCISE 2.3 B) Determine ENBW for the rectangular, Hamming, and Harris-Nuttall windows
#
# A Tabela abaixo apresenta a largura de banda de ruído equivalente (ENBW, Equivalent Noise BandWidth) para as três janelas.
#
# ##EXERCISE 2.3 C) Compare ENBW to the normalized 3-dB width for the windows in part (b)
#
# Basta comparar valores da segunda e terceira colunas da Tabela abaixo para as três janelas do item (b).

# %%
def equivalent_noise_bandwidth(window):
    #Returns the Equivalent Noise BandWidth (ENBW)
    return len(window) * np.sum(window**2) / np.sum(window)**2

def get_enbw_windows():
    #Return ENBW for all the following windows as a dataframe
    window_names = ["boxcar","barthann","bartlett","blackman","hamming","hann","nuttall","triang"]
    
    df = pd.DataFrame(columns=["Janela", "ENBW(bins)", "ENBW correção (3-dB)"])
    for window_name in window_names:
        method_name = window_name
        func_to_run = getattr(signal, method_name) #map window names to window functions in scipy package
        L = 41 #Number of points in the output window (variando L para observar a independencia de Hamming)
        window = func_to_run(L) #call the functions
        
        enbw = equivalent_noise_bandwidth(window) #compute ENBW
        
        df = df.append({"Janela": window_name.title(),"ENBW(bins)":round(enbw,2),"ENBW correção (3-dB)": round(10*np.log10(enbw),2)},ignore_index=True)
                       
    return df

df = get_enbw_windows() #call the function
df.head(15) #display dataframe
# Out:
#      Janela  ENBW(bins)  ENBW correção (3-dB)
# 0    Boxcar        1.00                  0.00
# 1  Barthann        1.49                  1.74
# 2  Bartlett        1.37                  1.36
# 3  Blackman        1.77                  2.48
# 4   Hamming        1.39                  1.42
# 5      Hann        1.54                  1.87
# 6   Nuttall        2.03                  3.07
# 7    Triang        1.30                  1.15

# %% [markdown]
# ##EXERCISE 2.4 A) Determine the **scallop loss** for some commonly used windows.
#
# Esta última linha de código pode ser rodada usando Matlab.

# %%
function s_l = scalloploss(len)
window = rectwin(len);
num_total = 0;
den_total = 0;

for n = 0:len-1
    A1 = exp(-((1i*(n)*pi)/len));
    A2 = window(n+1)*A1;
    num = A2;                      % !!
    den = abs(window(n+1));        % you also forgot the abs  here
    num_total = num_total + num;
    den_total = den_total + den;
end
num_total=abs(num_total);    % !!
result = 20*log(num_total/den_total);

s_l = result

# %%
scalloploss(41)

# %% [markdown]
# ##EXERCISE 2.4 B) *worst-case processing loss*.

# %%
#Worst-case processing loss é a soma da Scallop Loss e da ENBW
